# %% [markdown]
# **Engenharia de computação**
# **Vladimir Rodaly joseph**
#
# **Prof: Ronaldo Fernandes Ramos**
# ##Método de implementação de algoritmos ##

# %% [markdown]
# **Import Bibliotheca**

# %%
import numpy as np
from time import perf_counter
from pandas import DataFrame
from seaborn import pointplot, set_style

# Constante
LISTA_DE_TAMANHOS = np.array([1000, 2000, 3000,
                              4000, 5000, 8000,
                              11_000, 15_000])

# %% [markdown]
# **Implementation do algoritmo**

# %%
def _heapify(heap:np.ndarray, start:int, max_pos:int):
  pai = start
  while True:
    filho = 2 * pai + 1
    if filho > max_pos:
      break

    # Se ambos os filhos são posições válidas
    if filho + 1 <= max_pos and heap[filho] < heap[filho + 1]:
      filho += 1 # indica o maior filho

    if heap[pai] < heap[filho]:
      heap[pai], heap[filho] = heap[filho], heap[pai]
      pai = filho
    else:
      break


def in_place_heap(arr:np.ndarray):
  N = len(arr)

  # range((len(lst)-2)/2, -1, -1) # da metade de arr até o início
  for start in range((N-2)//2).__reversed__():
    _heapify(arr, start, N-1)

  for end in range(N-1, 0, -1):
    arr[end], arr[0] = arr[0], arr[end]
    _heapify(arr, 0, end - 1)

# %% [markdown]
# **Desempenho de testes**

# %%
data = dict()

for ordem in ['crescente', 'aleatoria', 'decrescente']:
  tempos = list()
  for tamanho in LISTA_DE_TAMANHOS:
    # Gerando amostra do teste
    if ordem == 'crescente':
      amostra = np.arange(tamanho, dtype=float)
    elif ordem == 'decrescente':
      amostra = np.arange(tamanho, dtype=float)[::-1].copy()
    else:
      amostra = np.random.sample(tamanho)

    # testando performance
    start = perf_counter()
    in_place_heap(amostra)
    stop = perf_counter()

    # salvando resultado
    tempos.append(stop - start)
  data[ordem] = tempos
data['tamanhos'] = LISTA_DE_TAMANHOS

df = DataFrame(data=data)
df.style.hide_index()
# Out:
# <ipython-input-4-98742c978abf>:25: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_728a5" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_728a5_level0_col0" class="col_heading level0 col0" >crescente</th>
#       <th id="T_728a5_level0_col1" class="col_heading level0 col1" >aleatoria</th>
#       <th id="T_728a5_level0_col2" class="col_heading level0 col2" >decrescente</th>
#       <th id="T_728a5_level0_col3" class="col_heading level0 col3" >tamanhos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_728a5_row0_col0" class="data row0 col0" >0.027609</td>
#       <td id="T_728a5_row0_col1" class="data row0 col1" >0.009086</td>
#       <td id="T_728a5_row0_col2" class="data row0 col2" >0.008501</td>
#       <td id="T_728a5_row0_col3" class="data row0 col3" >1000</td>
#     </tr>
#     <tr>
#       <td id="T_728a5_row1_col0" class="data row1 col0" >0.083622</td>
#       <td id="T_728a5_row1_col1" class="data row1 col1" >0.026501</td>
#       <td id="T_728a5_row1_col2" class="data row1 col2" >0.018912</td>
#       <td id="T_728a5_row1_col3" class="data row1 col3" >2000</td>
#     </tr>
#     <tr>
#       <td id="T_728a5_row2_col0" class="data row2 col0" >0.148870</td>
#       <td id="T_728a5_row2_col1" class="data row2 col1" >0.031585</td>
#       <td id="T_728a5_row2_col2" class="data row2 col2" >0.029868</td>
#       <td id="T_728a5_row2_col3" class="data row2 col3" >3000</td>
#     </tr>
#     <tr>
#       <td id="T_728a5_row3_col0" class="data row3 col0" >0.069978</td>
#       <td id="T_728a5_row3_col1" class="data row3 col1" >0.043705</td>
#       <td id="T_728a5_row3_col2" class="data row3 col2" >0.041695</td>
#       <td id="T_728a5_row3_col3" class="data row3 col3" >4000</td>
#     </tr>
#     <tr>
#       <td id="T_728a5_row4_col0" class="data row4 col0" >0.058515</td>
#       <td id="T_728a5_row4_col1" class="data row4 col1" >0.055980</td>
#       <td id="T_728a5_row4_col2" class="data row4 col2" >0.052896</td>
#       <td id="T_728a5_row4_col3" class="data row4 col3" >5000</td>
#     </tr>
#     <tr>
#       <td id="T_728a5_row5_col0" class="data row5 col0" >0.100042</td>
#       <td id="T_728a5_row5_col1" class="data row5 col1" >0.105996</td>
#       <td id="T_728a5_row5_col2" class="data row5 col2" >0.089074</td>
#       <td id="T_728a5_row5_col3" class="data row5 col3" >8000</td>
#     </tr>
#     <tr>
#       <td id="T_728a5_row6_col0" class="data row6 col0" >0.144845</td>
#       <td id="T_728a5_row6_col1" class="data row6 col1" >0.139669</td>
#       <td id="T_728a5_row6_col2" class="data row6 col2" >0.127936</td>
#       <td id="T_728a5_row6_col3" class="data row6 col3" >11000</td>
#     </tr>
#     <tr>
#       <td id="T_728a5_row7_col0" class="data row7 col0" >0.214241</td>
#       <td id="T_728a5_row7_col1" class="data row7 col1" >0.199843</td>
#       <td id="T_728a5_row7_col2" class="data row7 col2" >0.183448</td>
#       <td id="T_728a5_row7_col3" class="data row7 col3" >15000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Resultados Plots**

# %%
# Remodela o dataframe para uma versão longa mais fácil de plotar
long_df = df.melt(id_vars='tamanhos', var_name='ordenação', value_name='tempos')

set_style('darkgrid')
pointplot(
  data=long_df,
  x='tamanhos',
  y='tempos',
  hue='ordenação',
  ).set(
    xlabel='tamanho da amostra',
    ylabel='tempo (s)',
    title='TAMANHO DA LISTA X TEMPO DE ORDENAMENTO')

ordem = long_df.sort_values(by='tempos', ascending=False)['ordenação'].values[0]
print(f'O pior caso é quando a lista se encontra ordenada de forma {ordem}')
# Out:
# O pior caso é quando a lista se encontra ordenada de forma crescente
