# %%
import numpy as np
from timeit import default_timer as Timer
from timeit import timeit
from time import perf_counter, sleep
from random import randint
import matplotlib.pyplot as plt
import copy
#copy.deepcopy

# %%
#Vladimir Rodaly joseph

# %%
#decorator (medir o tempo)
def medirTempo(funcao):
  def calcula_tempo(tamanho):
    inicio = perf_counter()
    res = funcao(tamanho)
    fim = perf_counter()
    return res, fim-inicio
  return calcula_tempo

# %%
#gerar serie aleatoria em python
@medirTempo
def geraSerieAleatoria(tam):
  s = np.arange(0, tam, 1)
  np.random.shuffle(s)
  return s

# %%
s, t = geraSerieAleatoria(10)
print(f"Serie : {s}")
print(f"Tempo {t} segundos")
# Out:
# Serie : [4 8 1 9 0 3 5 2 6 7]
# Tempo 0.00012782599969796138 segundos

# %%
#gerar um serie totalmente invertida
@medirTempo
def geraSerieInvertida(tam):
  return np.arange(tam-1, -1, -1)

# %%
s, t = geraSerieInvertida(10)
print(f"Serie : {s}")
print(f"Tempo {t} segundos")
# Out:
# Serie : [9 8 7 6 5 4 3 2 1 0]
# Tempo 2.1887000002607238e-05 segundos

# %%
@medirTempo
def bubble_sort(array):
  n = len(array)
  for i in range(n):
    for j in range(0, n-i-1):
      if array[j] > array[j+1]:
        array[j], array[j+1] = array[j+1], array[j]
  return array

# %%
@medirTempo
def bubbleSort(S):
  mudanca = True
  while(mudanca):
    mudanca = False
    for i in range(len(S) - 1):
      if S[i] > S[i+1]:
        S[i], S[i+1] = S[i+1], S[i]
        mudanca = True
  return S

# %%
# bubblesort 3 (novo):
@medirTempo
def bubbleSort3(array):
    for x in range(len(array)):
        for y in range(len(array) - 1): #Esse -1 é para evitar checar fora dos limites do array
            if(array[y] > array[y+1]):
                temp = array[y]
                array[y] = array[y+1]
                array[y+1] = temp
    return array

# %%
#lista de  tamanhos
tamanhos = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
tamanhos1 = [10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
tamanhos2 = [10000, 20000, 30000, 40000, 50000]
tamanhos3 = [100000, 200000, 300000, 400000, 500000]
tamanhos4 = [1E+6, 2E+6, 3E+6, 4E+6, 5E+6]

# %%
bsM = []
#bsP = []

bsMS = []
#bsPS = []

bs3M = []
#bs3P = []

for tam in tamanhos:
  serie = geraSerieAleatoria(tam)
  #serie1 = geraSerieInvertida(tam)

  sc, _= copy.deepcopy(serie)
  #sc1, _ = copy.deepcopy(serie1)

  sc2, _ = copy.deepcopy(serie)
  #sc3, _ = copy.deepcopy(serie1)

  sc4, _ = copy.deepcopy(serie)
  #sc5, _ = copy.deepcopy(serie1)

  _, t = bubble_sort(sc)
  #_, t1 = bubble_sort(sc1)

  _, t2 = bubbleSort(sc2)
  #_, t3 = bubbleSort(sc3)

  _, t4 = bubbleSort3(sc4)
  #_, t5 = bubbleSort3(sc5)

  #print(f"Resultado {r}")
  #print(f"Tempo {t}")
  bsM.append(t)
  #bsP.append(t1)
  bsMS.append(t2)
  #bsPS.append(t3)
  bs3M.append(t4)
  #bs3P.append(t5)

# %%
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(15,5))
plt.plot(tamanhos, bsM, color='blue', label='bubble_sort')
#plt.plot(tamanhos, bsP, color='red', label='bubble_sort pior')
plt.plot(tamanhos, bsMS, color='lime',  label='bubbleSort(S)')
#plt.plot(tamanhos, bsPS, color='orange',  label='bubbleSort(S) pior')
plt.plot(tamanhos, bs3M, color='pink',  label='bubbleSort3(novo)')
#plt.plot(tamanhos, bs3P, color='purple',  label='bubbleSort3(novo) pior')
plt.legend(loc='upper left')
plt.xlabel('QTD testes')
plt.ylabel('Valores')
plt.show()

# %%
bsM = []
bsP = []

#bsMS = []
#bsPS = []

#bs3M = []
#bs3P = []

for tam in tamanhos2:
  serie = geraSerieAleatoria(tam)
  serie1 = geraSerieInvertida(tam)

  sc, _= copy.deepcopy(serie)
  sc1, _ = copy.deepcopy(serie1)

  #sc2, _ = copy.deepcopy(serie)
  #sc3, _ = copy.deepcopy(serie1)

  #sc4, _ = copy.deepcopy(serie)
  #sc5, _ = copy.deepcopy(serie1)

  _, t = bubble_sort(sc)
  _, t1 = bubble_sort(sc1)

  #_, t2 = bubbleSort(sc2)
  #_, t3 = bubbleSort(sc3)

  #_, t4 = bubbleSort3(sc4)
  #_, t5 = bubbleSort3(sc5)

  #print(f"Resultado {r}")
  #print(f"Tempo {t}")
  bsM.append(t)
  bsP.append(t1)
  #bsMS.append(t2)
  #bsPS.append(t3)
  #bs3M.append(t4)
  #bs3P.append(t5)

# %%
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(15,5))
plt.plot(tamanhos2, bsM, color='blue', label='bubble_sort medio')
plt.plot(tamanhos2, bsP, color='red', label='bubble_sort pior')
#plt.plot(tamanhos, bsMS, color='lime',  label='bubbleSort(S)')
#plt.plot(tamanhos, bsPS, color='orange',  label='bubbleSort(S) pior')
#plt.plot(tamanhos, bs3M, color='pink',  label='bubbleSort3(novo)')
#plt.plot(tamanhos, bs3P, color='purple',  label='bubbleSort3(novo) pior')
plt.legend(loc='upper left')
plt.xlabel('QTD testes')
plt.ylabel('Valores')
plt.show()

# %% [markdown]
# #selectionsort

# %%
import numpy as np
from timeit import default_timer as timer
from timeit import timeit
from time import perf_counter,sleep
from random import randint
import matplotlib.pyplot as plt
import copy
from tqdm.notebook import tqdm,trange
from scipy.stats import norm
from scipy.stats import ttest_ind

# %%
def medirTempo(funcao):
  def calcula_tempo(tamanho):
    inicio = perf_counter()
    res = funcao(tamanho)
    fim = perf_counter()
    return res, fim-inicio
  return calcula_tempo

# %%
@medirTempo
def geraSerieAleatoria(tam):
  s = np.arange(0, tam, 1)
  np.random.shuffle(s)
  return s

# %%
#gerar um serie totalmente invertida
@medirTempo
def geraSerieInvertida(tam):
  return np.arange(tam-1, -1, -1)

# %%
#Funcao select_sort 1
def select_sort1(array):
  for i in range(len(array)):
    menor = i
   # print(array)
    for j in range(i+1,len(array)):
        if array[i] < array[menor]:
          menor = j
    aux = array[menor]
    array[menor] = array[i]
    array[i] = aux
   # print(array)
  return array

# %%
#Funcao select_sort 2
def select_sort2(array):
  for i in range(len(array)):
   # print(array)
    for j in range(i+1,len(array)):
        if array[i] < array[j]:
          aux = array[j]
          array[j] = array[i]
          array[i] = aux
   # print(array)
  return array

# %%
#lista de  tamanhos
tamanhos = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
#tamanhos1 = [10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
#tamanhos2 = [10000, 20000, 30000, 40000, 50000]
#tamanhos3 = [100000, 200000, 300000, 400000, 500000]
#tamanhos4 = [1E+6, 2E+6, 3E+6, 4E+6, 5E+6]

# %%
selection_sortT1 = []
selection_sortT2 = []

for tam in tamanhos:
  s, t = geraSerieAleatoria(tam)
  s2 = copy.deepcopy(s)
  s3 = copy.deepcopy(s)

# %%
# funcao para serie ordenadas
  _, t1 = select_sort1(s)
  _, t2 = select_sort2(s2)

  selection_sortT1.append(t1)
  selection_sortT2.append(t2)

# %%
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(12, 6))
plt.plot(tamanhos, selection_sortT1, label='Selection Sort 1')
plt.plot(tamanhos, selection_sortT2, label='Selection Sort 2')
plt.xlabel('Tamanho da Lista')
plt.ylabel('Tempo')
plt.title('Selection Sort')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
#  # insertion sort

# %%
import numpy as np
from time import perf_counter
from seaborn import pointplot, set_style
from pandas import DataFrame

LISTA_DE_TAMANHOS = np.array([1000, 2000, 3000,
                              4000, 5000, 8000,
                              11_000, 15_000], dtype=int)

# %%
#Implantação do Insertion Sort
def insertion(arr:'np.ndarray[float]') -> None:
  n = len(arr)
  if n > 1:
    for i in range(1, n):
      atual = arr[i]
      j = i - 1
      while j >= 0 and arr[j] > atual:
        arr[j+1] = arr[j]
        j -= 1
      arr[j+1] = atual

# %% [markdown]
# **Desempenho**

# %%
data = dict()

for ordem in ['crescente', 'aleatoria', 'decrescente']:
  tempos = list()
  for tamanho in LISTA_DE_TAMANHOS:
    # Gerando amostra do teste
    if ordem == 'crescente':
      amostra = np.arange(tamanho, dtype=float)
    elif ordem == 'decrescente':
      amostra = np.arange(tamanho, dtype=float)[::-1].copy()
    else:
      amostra = np.random.sample(tamanho)

    # testando performance
    start = perf_counter()
    insertion(amostra)
    stop = perf_counter()

    # salvando resultado
    tempos.append(stop - start)
  data[ordem] = tempos
data['tamanhos'] = LISTA_DE_TAMANHOS

df = DataFrame(data=data)
df.style.hide_index()
# Out:
# <ipython-input-13-5dae96e45491>:25: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_1b6fe" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_1b6fe_level0_col0" class="col_heading level0 col0" >crescente</th>
#       <th id="T_1b6fe_level0_col1" class="col_heading level0 col1" >aleatoria</th>
#       <th id="T_1b6fe_level0_col2" class="col_heading level0 col2" >decrescente</th>
#       <th id="T_1b6fe_level0_col3" class="col_heading level0 col3" >tamanhos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1b6fe_row0_col0" class="data row0 col0" >0.000726</td>
#       <td id="T_1b6fe_row0_col1" class="data row0 col1" >0.371203</td>
#       <td id="T_1b6fe_row0_col2" class="data row0 col2" >0.189257</td>
#       <td id="T_1b6fe_row0_col3" class="data row0 col3" >1000</td>
#     </tr>
#     <tr>
#       <td id="T_1b6fe_row1_col0" class="data row1 col0" >0.005292</td>
#       <td id="T_1b6fe_row1_col1" class="data row1 col1" >1.421325</td>
#       <td id="T_1b6fe_row1_col2" class="data row1 col2" >0.773578</td>
#       <td id="T_1b6fe_row1_col3" class="data row1 col3" >2000</td>
#     </tr>
#     <tr>
#       <td id="T_1b6fe_row2_col0" class="data row2 col0" >0.008327</td>
#       <td id="T_1b6fe_row2_col1" class="data row2 col1" >2.811827</td>
#       <td id="T_1b6fe_row2_col2" class="data row2 col2" >1.734070</td>
#       <td id="T_1b6fe_row2_col3" class="data row2 col3" >3000</td>
#     </tr>
#     <tr>
#       <td id="T_1b6fe_row3_col0" class="data row3 col0" >0.003437</td>
#       <td id="T_1b6fe_row3_col1" class="data row3 col1" >6.053931</td>
#       <td id="T_1b6fe_row3_col2" class="data row3 col2" >3.132465</td>
#       <td id="T_1b6fe_row3_col3" class="data row3 col3" >4000</td>
#     </tr>
#     <tr>
#       <td id="T_1b6fe_row4_col0" class="data row4 col0" >0.020162</td>
#       <td id="T_1b6fe_row4_col1" class="data row4 col1" >3.671631</td>
#       <td id="T_1b6fe_row4_col2" class="data row4 col2" >6.386699</td>
#       <td id="T_1b6fe_row4_col3" class="data row4 col3" >5000</td>
#     </tr>
#     <tr>
#       <td id="T_1b6fe_row5_col0" class="data row5 col0" >0.017171</td>
#       <td id="T_1b6fe_row5_col1" class="data row5 col1" >7.753417</td>
#       <td id="T_1b6fe_row5_col2" class="data row5 col2" >15.867028</td>
#       <td id="T_1b6fe_row5_col3" class="data row5 col3" >8000</td>
#     </tr>
#     <tr>
#       <td id="T_1b6fe_row6_col0" class="data row6 col0" >0.023124</td>
#       <td id="T_1b6fe_row6_col1" class="data row6 col1" >13.484044</td>
#       <td id="T_1b6fe_row6_col2" class="data row6 col2" >27.017438</td>
#       <td id="T_1b6fe_row6_col3" class="data row6 col3" >11000</td>
#     </tr>
#     <tr>
#       <td id="T_1b6fe_row7_col0" class="data row7 col0" >0.029945</td>
#       <td id="T_1b6fe_row7_col1" class="data row7 col1" >25.133993</td>
#       <td id="T_1b6fe_row7_col2" class="data row7 col2" >51.775701</td>
#       <td id="T_1b6fe_row7_col3" class="data row7 col3" >15000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Plotar o grafico & Resultado**

# %%
# Remodela o dataframe para uma versão longa mais fácil de plotar
long_df = df.melt(id_vars='tamanhos', var_name='ordenação', value_name='tempos')

set_style('darkgrid')
pointplot(
  data=long_df,
  x='tamanhos',
  y='tempos',
  hue='ordenação',
  ).set(
    xlabel='tamanho da amostra',
    ylabel='tempo (s)',
    title='TAMANHO DA LISTA X TEMPO DE ORDENAMENTO')

ordem = long_df.sort_values(by='tempos', ascending=False)['ordenação'].values[0]
print(f'O pior caso é quando a lista se encontra ordenada de forma {ordem}')
# Out:
# O pior caso é quando a lista se encontra ordenada de forma decrescente
